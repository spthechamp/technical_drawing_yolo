# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/technical-drawing-dataset/technical_drawing_dataset/classes.txt
# /kaggle/input/technical-drawing-dataset/technical_drawing_dataset/val/labels/drawing2Images_DBM903904_SHT_1_REV_02_FPD_Eng_E1D8-1_png_jpg.rf.15e70effe179c9b66604c182b0b77819.txt
# /kaggle/input/technical-drawing-dataset/technical_drawing_dataset/val/labels/drawing2Images_DWG019879-1-1_png.rf.992de348e28f5e7ff46d32bdb222d038.txt
# /kaggle/input/technical-drawing-dataset/technical_drawing_dataset/val/labels/drawing2Images_c66ab0b17da14b7c892915010656f9c0-0001-1_png.rf.10f59412c55123f2e3cb9995170df5e4.txt
# /kaggle/input/technical-drawing-dataset/technical_drawing_dataset/val/labels/drawing2Images_b07826a-1-1_png.rf.8859199c4434e8078bf7a8c4b0b0f448.txt
# /kaggle/input/technical-drawing-dataset/technical_drawing_dataset/val/labels/drawing2Images_COVER-DN-75-SUPPORT-1_png.rf.c3a42eb271197d05443bca28aed93090.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.8 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 95.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.5 MB/s eta 0:00:00:00:0100:01
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO(model='yolov8m', task='detect')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 273MB/s]

# %%
model.train(data='/kaggle/input/technical-drawing-yaml/technical_drawing_yaml.yaml', epochs=500, batch=8)
# Out:
# Ultralytics 8.3.168 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model2 = YOLO(model='yolov8m.pt',task='detect')

# %%
model2.train(data='/kaggle/input/technical-drawing-yaml/technical_drawing_yaml.yaml', epochs=500, batch=8, imgsz=1280)
# Out:
# Ultralytics 8.3.168 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import shutil

# %%
shutil.make_archive('/kaggle/working/technical_drawing_trained','zip','/kaggle/working/runs')
# Out:
# '/kaggle/working/technical_drawing_trained.zip'
